# %% [markdown]
# # Ensemble:
#
# ## Ensemble learning involc=ves combing multiple individual machine learning models(often calles "base models" oe "weak learners").
# ## It helps to make more accurate and robust predictions than any single model could achieve.
# ## The idea is to leverage the strengths of diverse models and mitigate their weaknesses, leading to better overall performance.

# %% [markdown]
# ## Ensemble uses two types of methods:
# ### 1. Bagging:
# #### It creates a different training subsets from sample training data with replacement and the final output is based on majority voting. For example Random Forest
#
# ### 2.Boosting:
# #### It combines weak learners into strong learners by creating sequential models  such that the final model has the highest accuracy. for ADA BOOST, XG BOOST

# %% [markdown]
# ## Random Forest:
#
# ### Random forest is a popular ensemble learnign method used for both classificztion and regression tasks in machine learning.
# ### It is an extension of the "bagging" esemble technique and was introduced by Leo Breiman and Adele Culter.
# ### Random Forest is known for its simplicitly, effectiveness and ability to handle complex data and high-dimensional feature space.

# %% [markdown]
# ## Steps:
#
# ### 1: In the Random Forest model, a subset of data points and a subset of features is selected for constructing each decision tree. Simply put , n random records and m features are taken from the data set having k numbers of records.
# ### 2: Individuals decision trees are constructed for each sample.
# ### 3: Each decision tree will generate an output.
# ### 4: Final output is considered based on Majority Voting or Averaging for Classification and regression, respectively.

# %% [markdown]
# ## What is Boosting:
#
# ### -Ensemble techniqu
# ### -Combines weak learners
# ### -Built sequentially
# ### -Improves Previous errors

# %% [markdown]
# ## AdaBoost:
#
# ### Focus: Misclassifies Points
#
# ### Steps:
# #### 1. Train model
# #### 2. Increase weights of wrong points
# #### 3. Retrain
#
#
#
#                      M
#
# F(x) = sign(summation(alpham hm(x)))
#
#                  m=1

# %% [markdown]
# ## Gradient Boosting:
#
# ### Focus: Residual error
# ### Steps:
# #### 1. Initial prediction
# #### 2. Cslculated error
# #### 3. Train on error
#
#
# ### Fm(x) =  Fm-1(x) + hm(x)

# %%
1 - 0.5
# Out:
# 0.5

# %%
(-0.5 )* (0.1)
# Out:
# -0.05

# %% [markdown]
# features             |         AdaBoost             |           Gradient Boosting      |  XGBoost
#
# Focus                 |   Wrong Points              |     Errors                         |     Optimized errors
#
# Speed                 |    Slow                      |     Medium                          |     Fast
#
# Overfitting           |   High                       |       Medium                         |     Low
#
# Complexity             |   simple                     |     Moderate                        |      Advanced
