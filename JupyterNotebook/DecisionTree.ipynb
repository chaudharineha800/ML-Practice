# %% [markdown]
# # Decision Tree:
#
# # Works as if-else
# # it contains root node, Spliting,Branches/subtree,decision node,leaf node

# %% [markdown]
# ## Entropy:
# ### How much information we get from a column
# ## E(S) = summation (-pi log2 pi)
#
# Where pi in simply the frequentist probability of an elemnts / class 'i' in our data
#
# for e.g if our data has only 2 classs labels yes and No
#
# ## E(D) = -pyes log2 (pyes) - pno log2 (pno)

# %% [markdown]
# ### !. Entropy of parent:
#
# ### E(P)=-py log2 (py) - pn log2 (pn)
# ### =9/14log2(9/14)-5/14log2(5/14)
# ### =0.94

# %% [markdown]
# ### 2. Calcualte entropy of children
#
# ### E(S) = -2/5log2(2/5) - 3/5log2(3/5)
# ### E(s) = 0.97
#
# ### E(O)=-5/5log2(5/5) - 0/5log2(0/5)
# ### E(O)=0
#
# ### E(R) = -3/5log2(3/5)-2/5log2(2/5)

# %% [markdown]
# ## 3. Calculate weighted entropy of children
#
# ### Weighted Entropy = 5/14 * 0.97 + 4/14 * 0 + 5/14 * 0.97
# ### W.E(Children) = 0.69
#
# ### P Overcast is leaf node has its entropy of Zero

# %% [markdown]
# ### 4. Calculate Information Gain
#
# ### Infromation Gain = E(Parent) - {Weighted Average}* E(Children)
# ### IG = 0.97 - 0.69 =0.28
#
# ### So the information gain(or the decrease in entropy/impurity) when you split this data on the basis of Outlook condition/column is 0.28

# %% [markdown]
# ### 5. Calculate Information Gain for all the columns
#
# ###   Whichever column has the highest Information Gain(maximum decrease in entropy) the algorithm will select that column to split the data.

# %% [markdown]
# ### 6. Find Information Gain Recursively
# ###    Decision tree then applies a recursive greedy search algorithm in top bottom fashion to find Information Gain at every level of the tree
# ### Once a leaf node is reached(Entropy = 0), no more spliting is done

# %% [markdown]
# ## Gini Impurity
#
# ### Gini index is a measure of ipurity or purity used while creating a decision tree in the CART(Classification and  Regression Tree) algorithm.
# An Attribute with the low Gini index should be preferred as compared to the high Gini index.
# It only creates binary splits ad the CART alorithm uses the Gini index to create binaryu splits.
#
# # Gini Index : 1 - summation(jPj^2)

# %% [markdown]
# ### G = 1 - (py^2 + Pn^2)
# ### G = 1 - (4/25 + 9/25)
# ### G = 0.48

# %% [markdown]
# ### G = 1 - (Py^2 + Pn^2)
# ### G = 1 - (1/25 + 16/25)
# ### G = 0.32

# %%
d = {
    "salary":[20000,10000,60000,15000,12000],
    "age":[21,45,27,31,18],
    "purchase":["Yes","No","Yes","No","No"]
}

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.DataFrame(d)

# %%
df.head()
# Out:
#    salary  age purchase
# 0   20000   21      Yes
# 1   10000   45       No
# 2   60000   27      Yes
# 3   15000   31       No
# 4   12000   18       No

# %%
x = df.drop("purchase",axis=1)
y = df.purchase

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(x,y)
# Out:
# 1.0

# %%
ypred = dt.predict(x)

# %%
ypred
# Out:
# array(['Yes', 'No', 'Yes', 'No', 'No'], dtype=object)

# %%
dt.predict([[45000,29]])
# Out:
# C:\Users\chaud\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype=object)

# %%
from sklearn import tree

# %%
tree.plot_tree(dt.fit(x,y))
# Out:
# [Text(0.5, 0.75, 'x[0] <= 17500.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.625, 0.5, '  False')]
